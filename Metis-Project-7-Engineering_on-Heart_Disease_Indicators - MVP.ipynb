# %% [markdown]
# # Heart Disease Indicators app
# ## Metis Project 7 - Engineering on Heart Disease Indicators - MVP
#
# Krystian Krystkowiak 2022

# %% [markdown]
# ### Pipeline:

# %% [markdown]
# ![pipeline.jpg](attachment:pipeline.jpg)

# %% [markdown]
# ### After data acquisition and preprocessing, I created a Heart Disease Indicators app with informative plots that alows to browse through data and summarise key findings.

# %% [markdown]
# ![Screenshot%202022-11-26%20at%2020.04.08.png](attachment:Screenshot%202022-11-26%20at%2020.04.08.png)

# %% [markdown]
# ![Screenshot%202022-11-26%20at%2020.04.20.png](attachment:Screenshot%202022-11-26%20at%2020.04.20.png)

# %% [markdown]
# https://krystkowiakk-metis-project-7--streamlit-appstreamlit-app-xuz5iy.streamlit.app/

# %% [markdown]
# **Next:**
#
# - Storing data in SQL
# - Implementation of interactive form in the app that will use predictions from machine learning model.
